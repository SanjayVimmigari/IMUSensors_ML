# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv("C:\CMC_Project\Annotated_DATA.csv")
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 
# print(X)
# print(y)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.5)
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)
print("score on test: " + str(lr.score(x_test, y_test)))
print("score on train: "+ str(lr.score(x_train, y_train)))
# Out:
# score on test: 0.6451612903225806
# score on train: 0.696

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 
#print(X)
#print(y)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25)

models = {}

# Logistic Regression
from sklearn.linear_model import LogisticRegression
models['Logistic Regression'] = LogisticRegression()

# Support Vector Machines
from sklearn.svm import LinearSVC
models['Support Vector Machines'] = LinearSVC()

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
models['Decision Trees'] = DecisionTreeClassifier()

# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
models['Naive Bayes'] = GaussianNB()

# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
models['K-Nearest Neighbor'] = KNeighborsClassifier()

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    
    # Prediction 
    predictions = models[key].predict(x_test)
    
    # Calculate Accuracy, Precision and Recall Metrics
    accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    
import pandas as pd

df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
# df_model['Precision'] = precision.values()
# df_model['Recall'] = recall.values()

df_model
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#                          Accuracy Precision Recall
# Logistic Regression      0.691244       NaN    NaN
# Support Vector Machines  0.571429       NaN    NaN
# Decision Trees           0.875576       NaN    NaN
# Random Forest            0.935484       NaN    NaN
# Naive Bayes              0.792627       NaN    NaN
# K-Nearest Neighbor       0.903226       NaN    NaN

# %%
# !pip install --upgrade pip bleak

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv("C:\CMC_Project\Annotated_DATA.csv")
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1:-4] 
#print(X)
#print(y)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25)

models = {}



# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()



 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    
    # Prediction 
    predictions = models[key].predict(x_test)
    
    # Calculate Accuracy, Precision and Recall Metrics
    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)
    
import pandas as pd

df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()

df_model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)
# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25,random_state=None)

models = {}



# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()



 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    
    # Prediction 
    predictions = models[key].predict(x_test)
    print(predictions)
    # Calculate Accuracy, Precision and Recall Metrics
#     accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    from sklearn.metrics import accuracy_score
    
    x=accuracy_score(y_test, predictions)
    print(x)
    
    
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, predictions)
    print(cm)
    cm_df = pd.DataFrame(cm,
                     index = ['Backward','Forward','No Movement'], 
                     columns = ['Backward','Forward','No Movement'])
    #Plotting the confusion matrix
    plt.figure(figsize=(5,4))
    sns.heatmap(cm_df, annot=True)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()
    from sklearn.metrics import classification_report

    print(classification_report(y_test, predictions))
# import pandas as pd

# df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
# df_model['Accuracy'] = accuracy.values()
# df_model['Precision'] = precision.values()
# df_model['Recall'] = recall.values()

# df_model
# Out:
# [1 2 2 2 2 2 0 0 1 2 1 2 2 1 2 2 0 1 2 2 2 2 1 0 2 1 1 1 2 2 2 1 1 2 2 2 2
#  0 2 2 2 2 2 0 2 2 2 2 1 1 2 2 0 0 2 2 2 2 1 2 0 2 1 2 2 2 2 1 1 2 0 2 2 2
#  2 1 2 0 2 2 2 0 1 2 1 1 1 1 2 2 2 1 2 2 2 0 2 1 2 2 0 0 0 2 0 2 2 2 2 1 1
#  2 2 1 2 2 1 2 2 2 0 2 1 0 2 2 2 2 0 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 1 1
#  2 2 2 2 0 2 2 2 2 2 2 0 2 2 1 2 1 2 2 2 2 0 2 2 0 2 2 2 2 2 2 0 2 0 0 2 2
#  0 2 0 0 2 2 2 1 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 1 2 2 2 2 2]
# 0.9308755760368663
# [[ 25   2   0]
#  [  4  32   3]
#  [  3   3 145]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85        27
#            1       0.86      0.82      0.84        39
#            2       0.98      0.96      0.97       151
#
#     accuracy                           0.93       217
#    macro avg       0.88      0.90      0.89       217
# weighted avg       0.93      0.93      0.93       217

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn import metrics

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

n_estimators_list = list(range(10,220,50))
criterion_list = ['gini', 'entropy']
max_depth_list = list(range(5,41,10))
max_depth_list.append(None)
min_samples_split_list = [x/1000 for x in list(range(5, 41, 10))]
min_samples_leaf_list = [x/1000 for x in list(range(5, 41, 10))]
max_features_list = ['sqrt', 'log2']
params_grid = {
    'n_estimators': n_estimators_list,
    'criterion': criterion_list,
    'max_depth': max_depth_list,
    'min_samples_split': min_samples_split_list,
    'min_samples_leaf': min_samples_leaf_list,
    'max_features': max_features_list
}

def my_roc_auc_score(model, X, y): return metrics.roc_auc_score(y, model.predict(X))

model_rf = RandomizedSearchCV(estimator=RandomForestClassifier(class_weight='balanced'),
                              param_distributions=params_grid,
                              n_iter=50,
                              cv=3,
                              scoring=my_roc_auc_score,
                              return_train_score=True,
                              verbose=2)

model_rf.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# C:\Users\vinay\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\vinay\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "<ipython-input-33-562970fd3571>", line 30, in my_roc_auc_score
#     def my_roc_auc_score(model, X, y): return metrics.roc_auc_score(y, model.predict(X))
#   File "C:\Users\vinay\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\vinay\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py", line 536, in roc_auc_score
#     raise ValueError("multi_class must be in ('ovo', 'ovr')")
# ValueError: multi_class must be in ('ovo', 'ovr')
#
# ...

# %%
model_rf.best_params_
# Out:
# {'n_estimators': 60,
#  'min_samples_split': 0.005,
#  'min_samples_leaf': 0.015,
#  'max_features': 'sqrt',
#  'max_depth': 15,
#  'criterion': 'gini'}

# %%
rf_bst=RandomForestClassifier(n_estimators= 60,
                              min_samples_split= 0.005,
                              min_samples_leaf= 0.015,
                              max_features= 'sqrt',
                              max_depth= 15,
                              criterion= 'gini')

# %%
rf_bst.fit(x_train,y_train)
rf_bst.predict(x_test)
# Out:
# array([2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 1, 1,
#        1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 0, 2, 0, 2, 2, 2, 2, 2,
#        0, 2, 2, 2, 0, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2,
#        2, 0, 1, 2, 2, 1, 2, 2, 0, 2, 2, 1, 1, 0, 1, 1, 2, 2, 0, 1, 1, 2,
#        1, 0, 2, 2, 2, 0, 1, 2, 2, 0, 0, 2, 2, 1, 1, 2, 2, 1, 2, 2, 1, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 1, 2, 1, 2, 2, 2, 1, 0, 2,
#        2, 2, 1, 1, 1, 1, 2, 2, 2, 1, 0, 1, 2, 2, 2, 1, 1, 2, 0, 0, 1, 2,
#        1, 0, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2,
#        1, 2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 0, 2, 2, 2, 2, 2, 1, 2,
#        0, 1, 1, 0, 0, 1, 2, 0, 2, 1, 0, 2, 2, 2, 1, 2, 2, 2, 2],
#       dtype=int64)

# %%
from sklearn.metrics import accuracy_score
    
x=accuracy_score(y_test, predictions)
print(x)
    
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predictions)
print(cm)
cm_df = pd.DataFrame(cm,
                 index = ['Backward','Forward','No Movement'], 
                     columns = ['Backward','Forward','No Movement'])
    #Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
# 0.41935483870967744
# [[ 0  7 25]
#  [10  5 37]
#  [22 25 86]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        32
#            1       0.14      0.10      0.11        52
#            2       0.58      0.65      0.61       133
#
#     accuracy                           0.42       217
#    macro avg       0.24      0.25      0.24       217
# weighted avg       0.39      0.42      0.40       217

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\CMC_Project\fileIMU1_IMU2.csv")
X = data.iloc[:,0]  #independent columns
a_x = data.iloc[:,1] 
a_y = data.iloc[:,2] 
a_z = data.iloc[:,3] 

fig, (ax1,ax2,ax3) = plt.subplots(nrows=3, sharex=True, subplot_kw=dict(frameon=False)) # frameon=False removes frames
plt.axvline(x=1653586382.76, color='r', linestyle='-') # till here no movement
plt.axvline(x=1653586460.66, color='r', linestyle='-') # forward


# plt.axvline(x=1653586480.86, color='r', linestyle='-') #forward 
# plt.axvline(x=1653586485.24, color='r', linestyle='-') #backward

plt.axvline(x=1653586485.24, color='r', linestyle='-') #backward
plt.axvline(x=1653586552.0, color='r', linestyle='-')#no movement
plt.subplots_adjust(hspace=.0)
ax3.annotate("No Movement" ,xy=(1653586382.76, -29000), xytext=(1653586256.71, -29000))
ax3.annotate("Forward" ,xy=(1653586476.9, -29000), xytext=(1653586396.76, -29000))
ax3.annotate("Nm" ,xy=(1653586382.76, -29000), xytext=(1653586463.66, -29000))
ax3.annotate("Backward" ,xy=(1653586532.0, -29000), xytext=(1653586500.9, -29000))
# plt.xlim(1653586206.71,1653586572.0)

ax1.grid()
ax2.grid()
ax3.grid()
ax1.set_ylabel('a_x')
ax2.set_ylabel('a_y')
ax3.set_ylabel('a_z')

ax3.set_xlabel('time')



ax1.plot(X, a_x, color='r')
ax2.plot(X, a_y, color='y', linestyle='--')
ax3.plot(X, a_z, color='b', linestyle='--')
plt.savefig('DynamicGestures.png')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

#Subjects data  
df_sub1= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Arjun\arZzun_filemergedIMU1_IMU2.csv")
df_sub2= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Ajay\Ajay_filemergedIMU1_IMU2.csv")
df_sub3= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Rahu\Rahul_filemergedIMU1_IMU2.csv")

frames =  [df_sub2, df_sub3]
result= pd.concat(frames)

x_sub1= df_sub1.iloc[:,2:14]
y_sub1=df_sub1.iloc[:,-1]

x_sub2= df_sub2.iloc[:,1:13]
y_sub2=df_sub2.iloc[:,-1]

x_sub3= df_sub3.iloc[:,1:13]
y_sub3=df_sub3.iloc[:,-1]

x_sub= result.iloc[:,1:13]
y_sub=result.iloc[:,-1]


x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=None)

models = {}

# rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
# poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()
# models['Support Vector Machines'] =svm.SVC(kernel='poly', degree=3, C=1)

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    
    # Predictions
    predictions_testd = models[key].predict(x_test)
    predictions_sub1 = models[key].predict(x_sub1)
    predictions_sub2= models[key].predict(x_sub2)
    predictions_sub3= models[key].predict(x_sub3)
    predictions_sub= models[key].predict(x_sub)
    
#     print(predictions)
    # Calculate Accuracy, Precision and Recall Metrics
#     accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    from sklearn.metrics import accuracy_score
    xacc_testd=accuracy_score(y_test, predictions_testd)
    xacc_sub1=accuracy_score(y_sub1, predictions_sub1)
    xacc_sub2=accuracy_score(y_sub2, predictions_sub2)
    xacc_sub3=accuracy_score(y_sub3, predictions_sub3)
    xacc_sub=accuracy_score(y_sub, predictions_sub)
    
    print(xacc_testd)
#     print(xacc_sub1)
    print(xacc_sub)
#     print(xacc_sub3)
    print("Accuraccy of three subjects together:",xacc_sub2)
    
    from sklearn.metrics import confusion_matrix
    cm_testd = confusion_matrix(y_test, predictions_testd)
#     cm_sub1 = confusion_matrix(y_sub1, predictions_sub1)
    cm_sub2 = confusion_matrix(y_sub2, predictions_sub2)
#     cm_sub3 = confusion_matrix(y_sub3, predictions_sub3)
    cm_sub = confusion_matrix(y_sub, predictions_sub)
    
    print(cm_testd)
#     print(cm_sub1)
    print(cm_sub2)
#     print(cm_sub3)
    print(cm_sub)
    cm_df = pd.DataFrame(cm_testd,
                     index = ['Backward','Forward','No Movement'], 
                     columns = ['Backward','Forward','No Movement'])
    #Plotting the confusion matrix
    plt.figure(figsize=(5,4))
    sns.heatmap(cm_df, annot=True)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()
#     plt.savefig('TrainingData.png')
    
    cm_df1 = pd.DataFrame(cm_sub,
                     index = ['Backward','Forward','No Movement'], 
                     columns = ['Backward','Forward','No Movement'])
    #Plotting the confusion matrix
    plt.figure(figsize=(5,4))
    sns.heatmap(cm_df1, annot=True)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()
    plt.savefig('TotSubjectsData.png')
#     from sklearn.metrics import classification_report

#     print(classification_report(y_test, predictions))
# import pandas as pd

# df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
# df_model['Accuracy'] = accuracy.values()
# df_model['Precision'] = precision.values()
# df_model['Recall'] = recall.values()

# df_model
# Out:
# 0.9377880184331797
# 0.6457446808510638
# Accuraccy of three subjects together: 0.7008443908323281
# [[ 42   9   1]
#  [ 10  70   4]
#  [  0   3 295]]
# [[ 29  67  63]
#  [ 39 133  71]
#  [  1   7 419]]
# [[ 31  72 113]
#  [ 42 143  86]
#  [  4  16 433]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

#Subjects data  

df_sub2= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Ajay\Ajay_filemergedIMU1_IMU2.csv")

x_sub2= df_sub2.iloc[:,1:13]
y_sub2=df_sub2.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=None)

models = {}



# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
# # models['Random Forest'] = RandomForestClassifier(n_estimators= 60,
#                               min_samples_split= 0.005,
#                               min_samples_leaf= 0.015,
#                               max_features= 'sqrt',
#                               max_depth= 15,
#                               criterion= 'gini')
models['Random Forest'] = RandomForestClassifier(n_estimators= 150, random_state= 42)
# models['Logistic Regression'] = LogisticRegression()
# from sklearn.svm import LinearSVC
# models['Support Vector Machines'] = LinearSVC()

# # Decision Trees
# from sklearn.tree import DecisionTreeClassifier
# models['Decision Trees'] = DecisionTreeClassifier()

# # Naive Bayes
# from sklearn.naive_bayes import GaussianNB
# models['Naive Bayes'] = GaussianNB()

# # K-Nearest Neighbors
# from sklearn.neighbors import KNeighborsClassifier
# models['K-Nearest Neighbor'] = KNeighborsClassifier()

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
     
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    
    # Predictions
    predictions_testd = models[key].predict(x_test)
   
    predictions_sub2= models[key].predict(x_sub2)
    
    

    from sklearn.metrics import accuracy_score
    xacc_testd=accuracy_score(y_test, predictions_testd)
    xacc_sub2=accuracy_score(y_sub2, predictions_sub2)

    print(xacc_testd)
    print(xacc_sub2)
#     listx=[]
#     listx.append(xacc_sub2)
#     print(listx)
    from sklearn.metrics import confusion_matrix
    cm_testd = confusion_matrix(y_test, predictions_testd)
   
    cm_sub2 = confusion_matrix(y_sub2, predictions_sub2)
 
    print(cm_testd)
    print(cm_sub2)
     
    
#     cm_df = pd.DataFrame(cm,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
#     from sklearn.metrics import classification_report

#     print(classification_report(y_test, predictions))
# Out:
# 0.9170506912442397
# 0.7249698431845597
# [[ 44  14   2]
#  [  7  65   6]
#  [  1   6 289]]
# [[ 29  77  53]
#  [ 25 152  66]
#  [  1   6 420]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn import linear_model, tree, ensemble

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 


kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cnt = 1
# split()  method generate indices to split data into training and test set.
for train_index, test_index in kf.split(X, y):
    print(f'Fold:{cnt}, Train set: {len(train_index)}, Test set:{len(test_index)}')
    cnt+=1
    
# score = cross_val_score(ensemble.RandomForestClassifier(random_state= 42), X, y, cv= kf, scoring="accuracy")
# print(f'Scores for each fold are: {score}')
# print(f'Average score: {"{:.2f}".format(score.mean())}')

n_estimators = [50, 100, 150, 200, 250, 300, 350]

for val in n_estimators:
    score = cross_val_score(ensemble.RandomForestClassifier(n_estimators= val, random_state= 42), X, y, cv= kf, scoring="accuracy")
    print(f'Average score({val}): {"{:.3f}".format(score.mean())}')
# Out:
# Fold:1, Train set: 868, Test set:217
# Fold:2, Train set: 868, Test set:217
# Fold:3, Train set: 868, Test set:217
# Fold:4, Train set: 868, Test set:217
# Fold:5, Train set: 868, Test set:217
# Average score(50): 0.929
# Average score(100): 0.928
# Average score(150): 0.935
# Average score(200): 0.933
# Average score(250): 0.931
# Average score(300): 0.932
# Average score(350): 0.933

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.metrics import accuracy_score

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

#Subjects data  
df_sub1= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Arjun\arZzun_filemergedIMU1_IMU2.csv")
df_sub2= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Ajay\Ajay_filemergedIMU1_IMU2.csv")
df_sub3= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Rahu\Rahul_filemergedIMU1_IMU2.csv")

frames =  [df_sub2, df_sub3]
result= pd.concat(frames)

x_sub1= df_sub1.iloc[:,2:14]
y_sub1=df_sub1.iloc[:,-1]

x_sub2= df_sub2.iloc[:,1:13]
y_sub2=df_sub2.iloc[:,-1]

x_sub3= df_sub3.iloc[:,1:13]
y_sub3=df_sub3.iloc[:,-1]

x_sub= result.iloc[:,1:13]
y_sub=result.iloc[:,-1]


x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=None)
x_trainmix, x_testmix, y_trainmix, y_testmix = train_test_split(x_sub, y_sub, test_size=0.4, random_state=None)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x_sub2, y_sub2, test_size=0.4, random_state=None)


models = {}
models2 = {}
modelsmix = {}

# rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
# poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()
# models['Support Vector Machines'] =svm.SVC(kernel='poly', degree=3, C=1)

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier model
    models[key].fit(x_train, y_train)
    predictions_testd = models[key].predict(x_test)
    xacc_testd=accuracy_score(y_test, predictions_testd)
    print(xacc_testd)    
# for key in modelsmix.keys(): 
    
    modelsmix[key].fit(x_trainmix, y_trainmix)
    predictions_sub= modelsmix[key].predict(x_testmix)
    xacc_sub=accuracy_score(y_testmix, predictions_sub)
    print(xacc_sub)
# for key in models2.keys():    
    
    models2[key].fit(x_train2, y_train2)
    predictions_sub2= models2[key].predict(x_test2)
    xacc_sub2=accuracy_score(y_test2, predictions_sub2)
    print(xacc_sub2)
    # Predictions
    
#     predictions_sub1 = models[key].predict(x_sub1)
   
#     predictions_sub3= models[key].predict(x_sub3)
    
    
#     print(predictions)
    # Calculate Accuracy, Precision and Recall Metrics
#     accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    
   
#     xacc_sub1=accuracy_score(y_sub1, predictions_sub1)
    
#     xacc_sub3=accuracy_score(y_sub3, predictions_sub3)
    
    
   
#     print(xacc_sub1)
#     print(xacc_sub2)
# #     print(xacc_sub3)
#     print("Accuraccy of three subjects together:",xacc_sub)
    
#     from sklearn.metrics import confusion_matrix
#     cm_testd = confusion_matrix(y_test, predictions_testd)
# #     cm_sub1 = confusion_matrix(y_sub1, predictions_sub1)
#     cm_sub2 = confusion_matrix(y_sub2, predictions_sub2)
# #     cm_sub3 = confusion_matrix(y_sub3, predictions_sub3)
#     cm_sub = confusion_matrix(y_sub, predictions_sub)
    
#     print(cm_testd)
# #     print(cm_sub1)
#     print(cm_sub2)
# #     print(cm_sub3)
#     print(cm_sub)
#     cm_df = pd.DataFrame(cm_testd,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
# #     plt.savefig('TrainingData.png')
    
#     cm_df1 = pd.DataFrame(cm_sub,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df1, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
#     plt.savefig('TotSubjectsData.png')
# #     from sklearn.metrics import classification_report

# #     print(classification_report(y_test, predictions))
# # import pandas as pd

# # df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
# # df_model['Accuracy'] = accuracy.values()
# # df_model['Precision'] = precision.values()
# # df_model['Recall'] = recall.values()

# # df_model
# Out:
# 0.9078341013824884
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1fe5c208fab4> in <module>
#      63 # for key in modelsmix.keys():
#      64
# ---> 65     modelsmix[key].fit(x_trainmix, y_trainmix)
#      66     predictions_sub= modelsmix[key].predict(x_testmix)
#      67     xacc_sub=accuracy_score(y_testmix, predictions_sub)
#
# KeyError: 'Random Forest'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.metrics import accuracy_score

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

#Subjects data  
df_sub1= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Arjun\arZzun_filemergedIMU1_IMU2.csv")
df_sub2= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Ajay\Ajay_filemergedIMU1_IMU2.csv")
df_sub3= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Rahu\Rahul_filemergedIMU1_IMU2.csv")

frames =  [df_sub2, df_sub3]
result= pd.concat(frames)

x_sub1= df_sub1.iloc[:,2:14]
y_sub1=df_sub1.iloc[:,-1]

x_sub2= df_sub2.iloc[:,1:13]
y_sub2=df_sub2.iloc[:,-1]

x_sub3= df_sub3.iloc[:,1:13]
y_sub3=df_sub3.iloc[:,-1]

x_sub= result.iloc[:,1:13]
y_sub=result.iloc[:,-1]


x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=None)
x_trainmix, x_testmix, y_trainmix, y_testmix = train_test_split(x_sub, y_sub, test_size=0.4, random_state=None)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x_sub2, y_sub2, test_size=0.4, random_state=None)


# models = {}
models2 = {}
# modelsmix = {}

# rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
# poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models2['Random Forest'] = RandomForestClassifier()
# models['Support Vector Machines'] =svm.SVC(kernel='poly', degree=3, C=1)

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
#     # Fit the classifier model
#     models[key].fit(x_train, y_train)
#     predictions_testd = models[key].predict(x_test)
#     xacc_testd=accuracy_score(y_test, predictions_testd)
#     print(xacc_testd)    
# # for key in modelsmix.keys(): 
    
#     modelsmix[key].fit(x_trainmix, y_trainmix)
#     predictions_sub= modelsmix[key].predict(x_testmix)
#     xacc_sub=accuracy_score(y_testmix, predictions_sub)
#     print(xacc_sub)
# # for key in models2.keys():    
    
    models2[key].fit(x_train2, y_train2)
    predictions_sub2= models2[key].predict(x_test2)
    xacc_sub2=accuracy_score(y_test2, predictions_sub2)
    print(xacc_sub2)
    # Predictions
    
#     predictions_sub1 = models[key].predict(x_sub1)
   
#     predictions_sub3= models[key].predict(x_sub3)
    
    
#     print(predictions)
    # Calculate Accuracy, Precision and Recall Metrics
#     accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    
   
#     xacc_sub1=accuracy_score(y_sub1, predictions_sub1)
    
#     xacc_sub3=accuracy_score(y_sub3, predictions_sub3)
    
    
   
#     print(xacc_sub1)
#     print(xacc_sub2)
# #     print(xacc_sub3)
#     print("Accuraccy of three subjects together:",xacc_sub)
    
#     from sklearn.metrics import confusion_matrix
#     cm_testd = confusion_matrix(y_test, predictions_testd)
# #     cm_sub1 = confusion_matrix(y_sub1, predictions_sub1)
#     cm_sub2 = confusion_matrix(y_sub2, predictions_sub2)
# #     cm_sub3 = confusion_matrix(y_sub3, predictions_sub3)
#     cm_sub = confusion_matrix(y_sub, predictions_sub)
    
#     print(cm_testd)
# #     print(cm_sub1)
#     print(cm_sub2)
# #     print(cm_sub3)
#     print(cm_sub)
#     cm_df = pd.DataFrame(cm_testd,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
# #     plt.savefig('TrainingData.png')
    
#     cm_df1 = pd.DataFrame(cm_sub,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df1, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
#     plt.savefig('TotSubjectsData.png')
# #     from sklearn.metrics import classification_report

# #     print(classification_report(y_test, predictions))
# # import pandas as pd

# # df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
# # df_model['Accuracy'] = accuracy.values()
# # df_model['Precision'] = precision.values()
# # df_model['Recall'] = recall.values()

# # df_model
# Out:
# 0.8945783132530121

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.metrics import accuracy_score

data = pd.read_csv("C:\CMC_Project\Annotated_DATA_Copy.csv")
#Train data
X = data.iloc[:,1:13]  #independent columns
y = data.iloc[:,-1] 

#Subjects data  
df_sub1= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Arjun\arZzun_filemergedIMU1_IMU2.csv")
df_sub2= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Ajay\Ajay_filemergedIMU1_IMU2.csv")
df_sub3= pd.read_csv(r"C:\CMC_Project\DATA_COLLECTED\Ble_check\Ble_check\IMU_Data\Rahu\Rahul_filemergedIMU1_IMU2.csv")

frames =  [df_sub2, df_sub3]
result= pd.concat(frames)

x_sub1= df_sub1.iloc[:,2:14]
y_sub1=df_sub1.iloc[:,-1]

x_sub2= df_sub2.iloc[:,1:13]
y_sub2=df_sub2.iloc[:,-1]

x_sub3= df_sub3.iloc[:,1:13]
y_sub3=df_sub3.iloc[:,-1]

x_sub= result.iloc[:,1:13]
y_sub=result.iloc[:,-1]


x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=None)
x_trainmix, x_testmix, y_trainmix, y_testmix = train_test_split(x_sub, y_sub, test_size=0.4, random_state=None)
x_train2, x_test2, y_train2, y_test2 = train_test_split(x_sub2, y_sub2, test_size=0.4, random_state=None)


models = {}
# models2 = {}
# modelsmix = {}

# rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
# poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()
# models['Support Vector Machines'] =svm.SVC(kernel='poly', degree=3, C=1)

 
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
#     # Fit the classifier model
#     models[key].fit(x_train, y_train)
#     predictions_testd = models[key].predict(x_test)
#     xacc_testd=accuracy_score(y_test, predictions_testd)
#     print(xacc_testd)    
# for key in modelsmix.keys(): 
    
    models[key].fit(x_trainmix, y_trainmix)
    predictions_sub= models[key].predict(x_testmix)
    xacc_sub=accuracy_score(y_testmix, predictions_sub)
    print(xacc_sub)
# for key in models2.keys():    
    
#     models2[key].fit(x_train2, y_train2)
#     predictions_sub2= models2[key].predict(x_test2)
#     xacc_sub2=accuracy_score(y_test2, predictions_sub2)
#     print(xacc_sub2)
    # Predictions
    
#     predictions_sub1 = models[key].predict(x_sub1)
   
#     predictions_sub3= models[key].predict(x_sub3)
    
    
#     print(predictions)
    # Calculate Accuracy, Precision and Recall Metrics
#     accuracy[key] = accuracy_score(predictions, y_test)
#     precision[key] = precision_score(predictions, y_test)
#     recall[key] = recall_score(predictions, y_test)
    
   
#     xacc_sub1=accuracy_score(y_sub1, predictions_sub1)
    
#     xacc_sub3=accuracy_score(y_sub3, predictions_sub3)
    
    
   
#     print(xacc_sub1)
#     print(xacc_sub2)
# #     print(xacc_sub3)
#     print("Accuraccy of three subjects together:",xacc_sub)
    
#     from sklearn.metrics import confusion_matrix
#     cm_testd = confusion_matrix(y_test, predictions_testd)
# #     cm_sub1 = confusion_matrix(y_sub1, predictions_sub1)
#     cm_sub2 = confusion_matrix(y_sub2, predictions_sub2)
# #     cm_sub3 = confusion_matrix(y_sub3, predictions_sub3)
#     cm_sub = confusion_matrix(y_sub, predictions_sub)
    
#     print(cm_testd)
# #     print(cm_sub1)
#     print(cm_sub2)
# #     print(cm_sub3)
#     print(cm_sub)
#     cm_df = pd.DataFrame(cm_testd,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
# #     plt.savefig('TrainingData.png')
    
#     cm_df1 = pd.DataFrame(cm_sub,
#                      index = ['Backward','Forward','No Movement'], 
#                      columns = ['Backward','Forward','No Movement'])
#     #Plotting the confusion matrix
#     plt.figure(figsize=(5,4))
#     sns.heatmap(cm_df1, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Values')
#     plt.xlabel('Predicted Values')
#     plt.show()
#     plt.savefig('TotSubjectsData.png')
# #     from sklearn.metrics import classification_report

# #     print(classification_report(y_test, predictions))
# # import pandas as pd

# # df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
# # df_model['Accuracy'] = accuracy.values()
# # df_model['Precision'] = precision.values()
# # df_model['Recall'] = recall.values()

# # df_model
# Out:
# 0.8111702127659575
